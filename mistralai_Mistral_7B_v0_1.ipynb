# %% [markdown]
# <a href="https://colab.research.google.com/github/saribasmetehan/Mistral-7B-practices/blob/main/mistralai_Mistral_7B_v0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers

# %%
import transformers
transformers.__version__
# Out:
# '4.41.2'

# %%
# !pip install -q accelerate bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 53.3 MB/s eta 0:00:00

# %%
from transformers import BitsAndBytesConfig

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
)

# %%
# !pip install -q transformers torch

# %%
import huggingface_hub
huggingface_hub.login(token='---- Replace User Access Tokens---')
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !pip install -q accelerate

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "mistralai/Mistral-7B-v0.1"
tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config = bnb_config,
    torch_dtype = torch.bfloat16,
    device_map = "auto",
    trust_remote_code = True,
    )
# Out:
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %%
from transformers import pipeline

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
)

# %%
promt = "What is tihs Young Turk Revolution?"

# %%
sequence = pipe(
    promt,
    do_sample=True,
    max_length=100,
    temperature=0.3,
    top_k= 50,
    top_p= 0.95,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    pad_token_id=tokenizer.eos_token_id,
)

# %%
print(sequence[0]["generated_text"])
# Out:
# What is tihs Young Turk Revolution?
#
# The Young Turk Revolution was a series of political reforms in the Ottoman Empire, which took place between 1908 and 1918. The revolution was led by the Committee of Union and Progress (CUP), a secret society of young Ottoman officers and intellectuals. The CUP overthrew the autocratic regime of Sultan Abdul Hamid II and established a constitutional monarchy. The revolution marked the
